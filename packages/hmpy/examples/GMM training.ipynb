# %%
from hmpy import*  
arm = arm_gesture(main_path = "data")
#arm.trainAllGestures([0.59,.69,.55,.59,.69], False)
#models = arm.loadAllGestures(th = [100,100,100,100,100])
models = arm.loadAllGestures(th = [50,100,100,45,100])
# Out:
# New path: data
# Name of the gestures : ['batting', 'hand_up', 'karate', 'katana', 'strech_up']
#
#  *** Loading model ***
# threashold = 100
# Type = 3IMU_acc model
# No features of Gravity and Body
# plotting GMM models
# data/models/batting
#
#  *** Loading model ***
# threashold = 100
# Type = 3IMU_acc model
# No features of Gravity and Body
# plotting GMM models
# data/models/hand_up
#
#  *** Loading model ***
# threashold = 100
# Type = 3IMU_acc model
# No features of Gravity and Body
# plotting GMM models
# data/models/karate
#
#  *** Loading model ***
# threashold = 100
# Type = 3IMU_acc model
# No features of Gravity and Body
# plotting GMM models
# data/models/katana
#
#  *** Loading model ***
# threashold = 100
# Type = 3IMU_acc model
# No features of Gravity and Body
# plotting GMM models
# data/models/strech_up

# %%
arm.validateGestureModels(models, 30)
# Out:
# ********* Validation **********
# New classifier
# window size of gesture *batting* is:66
# New classifier
# window size of gesture *hand_up* is:117
# New classifier
# window size of gesture *karate* is:56
# New classifier
# window size of gesture *katana* is:74
# New classifier
# window size of gesture *strech_up* is:137
# Datset used to validation: batting/acc1.txt
# Saving ... data/raw/batting/batting1.png
# Datset used to validation: batting/acc2.txt
# Saving ... data/raw/batting/batting2.png
# Datset used to validation: batting/acc3.txt
# Saving ... data/raw/batting/batting3.png
# Datset used to validation: batting/acc4.txt
# Saving ... data/raw/batting/batting4.png
# Datset used to validation: batting/acc5.txt
# Saving ... data/raw/batting/batting5.png
# Datset used to validation: batting/acc6.txt
# Saving ... data/raw/batting/batting6.png
# Datset used to validation: batting/acc7.txt
# Saving ... data/raw/batting/batting7.png
# Datset used to validation: batting/acc8.txt
# ...

# %%
#from hmpy import*
arm = arm_gesture("C:\Users\kike\Documents\GitHub\NEP-V5\packages\hmpy\examples\data")
#arm.trainSingleGesture("katana")
model = arm.loadSingleGesture("katana", th = 100)
list_one_model = [model]
arm.validateGestureModels(list_one_model,40)
# Out:
# New path: C:\Users\kike\Documents\GitHub\NEP-V5\packages\hmpy\examples\data
# Name of the gestures : ['batting', 'hand_up', 'karate', 'katana', 'strech_up']
#
#  *** Loading model ***
# threashold = 100
# Type = 3IMU_acc model
# No features of Gravity and Body
# plotting GMM models
# C:\Users\kike\Documents\GitHub\NEP-V5\packages\hmpy\examples\data/models/katana
# ********* Validation **********
# New classifier
# window size of gesture *katana* is:74
# Datset used to validation: katana/acc1.txt
# Saving ... C:\Users\kike\Documents\GitHub\NEP-V5\packages\hmpy\examples\data/raw/katana/katana1.png
# Datset used to validation: katana/acc2.txt
# Saving ... C:\Users\kike\Documents\GitHub\NEP-V5\packages\hmpy\examples\data/raw/katana/katana2.png
# Datset used to validation: katana/acc3.txt
# Saving ... C:\Users\kike\Documents\GitHub\NEP-V5\packages\hmpy\examples\data/raw/katana/katana3.png
# Datset used to validation: katana/acc4.txt
# ...
